# %% [markdown]
# ### 1. Import data and libraries

# %%
import numpy as np
import pandas as pd
import os
import sys
import random
import sklearn
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("abalone_data.txt")
data.head(5)
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %%
#check missing values
data.isnull().sum()
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole weight      0
# Shucked weight    0
# Viscera weight    0
# Shell weight      0
# Rings             0
# dtype: int64

# %% [markdown]
# ### 2. Explore the dataset

# %% [markdown]
# #### 2.1 Visulise correlation

# %%
# %matplotlib inline
#Observe colinearality
sns.pairplot(data.iloc[:,0:8],hue="Sex",palette="husl",markers=["o", "s", "D"])

# %%
#Visualize pariwise correlation
sns.pairplot(data,hue="Sex",palette="husl",kind='reg',markers=["o", "s", "D"],plot_kws={'line_kws':{'color':'orange'}, 'scatter_kws': {'alpha': 0.1}})
plt.show()
# %matplotlib inline

# %%
# correlation
data.corr()
# Out:
#                   Length  Diameter    Height  Whole weight  Shucked weight  \
# Length          1.000000  0.986812  0.827554      0.925261        0.897914
# Diameter        0.986812  1.000000  0.833684      0.925452        0.893162
# Height          0.827554  0.833684  1.000000      0.819221        0.774972
# Whole weight    0.925261  0.925452  0.819221      1.000000        0.969405
# Shucked weight  0.897914  0.893162  0.774972      0.969405        1.000000
# Viscera weight  0.903018  0.899724  0.798319      0.966375        0.931961
# Shell weight    0.897706  0.905330  0.817338      0.955355        0.882617
# Rings           0.556720  0.574660  0.557467      0.540390        0.420884
#
#                 Viscera weight  Shell weight     Rings
# Length                0.903018      0.897706  0.556720
# Diameter              0.899724      0.905330  0.574660
# Height                0.798319      0.817338  0.557467
# Whole weight          0.966375      0.955355  0.540390
# ...

# %%
ax = sns.heatmap(data.corr(), linewidth=0.5,cbar=True,cmap="YlGnBu")
plt.figure(figsize = (12,7))
plt.show()

# %% [markdown]
# Serveral Observations from above plot & table:
# 1. Number of rings (age) is positive correlated with almost all the quantitative features.
# 2. Many features are highly correlated, for example, length & diameter, length & all kinds of weight, length & height; whole weight & shucked weight, whole weight & viscera weight, whole weight &shell weight. It seems that length, diameter & whole weight are correlated with most of the other features.

# %% [markdown]
# #### 2.2 Visulise distribution

# %%
data.describe()
# Out:
#             Length     Diameter       Height  Whole weight  Shucked weight  \
# count  4177.000000  4177.000000  4177.000000   4177.000000     4177.000000
# mean      0.523992     0.407881     0.139516      0.828742        0.359367
# std       0.120093     0.099240     0.041827      0.490389        0.221963
# min       0.075000     0.055000     0.000000      0.002000        0.001000
# 25%       0.450000     0.350000     0.115000      0.441500        0.186000
# 50%       0.545000     0.425000     0.140000      0.799500        0.336000
# 75%       0.615000     0.480000     0.165000      1.153000        0.502000
# max       0.815000     0.650000     1.130000      2.825500        1.488000
#
#        Viscera weight  Shell weight        Rings
# count     4177.000000   4177.000000  4177.000000
# mean         0.180594      0.238831     9.933684
# std          0.109614      0.139203     3.224169
# min          0.000500      0.001500     1.000000
# ...

# %%
plt.figure(figsize=(8,5), dpi=80)
data.iloc[:,1:9].boxplot()
plt.ylabel(("Quartile Ranges"))
plt.show()

# %% [markdown]
# As we can see that the last column, rings, is out of the scale of the others, so plot again without it.

# %%
plt.figure(figsize=(8,5), dpi=80)
data.iloc[:,1:8].boxplot()
plt.ylabel(("Quartile Ranges"))
plt.show()

# %% [markdown]
# ##### Take a look at of the distribution within each gender.

# %%
plt.figure(figsize=(12,7), dpi=80)
plt.subplot(2,2,1)
data.loc[data['Sex']=='M','Rings'].hist()
plt.subplot(2,2,2)
data.loc[data['Sex']=='F','Rings'].hist()
plt.subplot(2,2,3)
data.loc[data['Sex']=='I','Rings'].hist()
print("The distribution of Rings in the three genders:\n",data.groupby('Sex')["Rings"].describe())
plt.show()
# Out:
# The distribution of Rings in the three genders:
#        count       mean       std  min  25%   50%   75%   max
# Sex
# F    1307.0  11.129304  3.104256  5.0  9.0  10.0  12.0  29.0
# I    1342.0   7.890462  2.511554  1.0  6.0   8.0   9.0  21.0
# M    1528.0  10.705497  3.026349  3.0  9.0  10.0  12.0  27.0

# %% [markdown]
# We can see that the differences in distribution of Ring numbers in each category M, F & I.

# %%
# Count how many samples are in each sex group
data.groupby("Sex")['Sex'].count()
# Out:
# Sex
# F    1307
# I    1342
# M    1528
# Name: Sex, dtype: int64

# %% [markdown]
# ### 3. Linear regression in scikit-learn

# %% [markdown]
# #### 3.1 Create Dummy variables for Sex column.

# %%
data_num = pd.get_dummies(data,drop_first=True)  #prefix=['M','F','I']
data_num.head()
# Out:
#    Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight  Rings  Sex_I  Sex_M
# 0         0.150     15      0      1
# 1         0.070      7      0      1
# 2         0.210      9      0      0
# 3         0.155     10      0      1
# 4         0.055      7      1      0

# %% [markdown]
# #### 3.2 split train - test dataset

# %%
from sklearn.cross_validation import train_test_split
feature_cols = ['Length','Diameter','Height','Whole weight','Shucked weight','Viscera weight','Shell weight','Sex_I','Sex_M']
X = data_num[feature_cols]
y = data_num["Rings"]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)
# Out:
# /Users/yangcao/anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
print("No. (samples, features) in training predictors:",X_train.shape)
print("No. samples in training response:", y_train.shape)
print("No. (samples, features) in test predictors:", X_test.shape)
print("No. samples in testing response:", y_test.shape)
# Out:
# No. (samples, features) in training predictors: (3341, 9)
# No. samples in training response: (3341,)
# No. (samples, features) in test predictors: (836, 9)
# No. samples in testing response: (836,)

# %% [markdown]
# #### 3.3 train the regression model and make prediction

# %%
# import model
from sklearn.linear_model import LinearRegression

# instantiate
linreg = LinearRegression()

# fit the model to the training data (learn the coefficients)
linreg.fit(X_train, y_train)

# print the intercept and coefficients
print("beta0",linreg.intercept_)

# pair the feature names with the coefficients
list(zip(feature_cols, linreg.coef_))
# Out:
# beta0 3.84115008942
# [('Length', -0.96832150802831107),
#  ('Diameter', 12.06428787859886),
#  ('Height', 9.6508677128120031),
#  ('Whole weight', 8.7478008848814302),
#  ('Shucked weight', -19.871623121423287),
#  ('Viscera weight', -9.7767397730053638),
#  ('Shell weight', 9.1792787646354945),
#  ('Sex_I', -0.78257360546356847),
#  ('Sex_M', 0.066818878388480371)]

# %% [markdown]
# #### 3.4 make prediction

# %%
# make predictions on the testing set
y_pred = linreg.predict(X_test)

# %% [markdown]
# ### 4. Model evaluation metrics for regression

# %% [markdown]
# #### 4.1 Computing the MSE & RMSE for our Number of Rings predictions

# %%
# calculate MSE
from sklearn import metrics
print("MSE: %.2f"% metrics.mean_squared_error(y_test,y_pred))
print('R2: %.2f' % metrics.r2_score(y_test,y_pred))
print('RMSE: %.2f' % np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# MSE: 4.77
# R2: 0.51
# RMSE: 2.18

# %% [markdown]
# Observation: The R2 is relatively low. Only 51% of variance is explained.
# Linear regression is sensitive to correlated variables. I'll first try to remove some of the highly correlated ones. In this case, I'll only remain Sex_I, Sex_M, Diameter,
# Or, more non-linearality is needed.

# %%
# Plot the residule to ovbserve the non-linearality 
plt.figure(figsize=(12,4))
residual = y_test - y_pred

# Plot the residual vs. predicted value to observe if the right type of equation is used, and if Variance is constant.
# In this case, apparently not. 
plt.subplot(1,2,1)
plt.scatter(x=y_pred, y=residual,)
plt.xlabel('prediction values (Number of Rings)')
plt.ylabel('Residual')

# Error terms should have a Normal Distribution
plt.subplot(1,2,2)
residual.hist()
plt.xlabel('Residual')
# Out:
# Text(0.5,0,'Residual')

# %% [markdown]
# #### 4.2 Remove or combine features with high correlation and not increasing much in RMSE

# %%
#After some exploration, I found that diameter and length can be dropped. 

feature_cols_2 = ["Sex_I","Sex_M","Whole weight","Shucked weight","Shell weight","Viscera weight","Height"] 
X_2 = data_num[feature_cols_2]
y_2 = data_num["Rings"]
X_train_2, X_test_2, y_train_2, y_test_2 = train_test_split(X_2, y_2, test_size=0.2, random_state=1)

# %%
# instantiate
linreg_2 = LinearRegression()
# fit the model to the training data (learn the coefficients)
linreg.fit(X_train_2, y_train_2)
print(linreg.intercept_)
print(linreg.coef_)

# pair the feature names with the coefficients
list(zip(feature_cols, linreg.coef_))

# make predictions on the testing set
y_pred_2 = linreg.predict(X_test_2)

#Model evaluation
print("MSE: %.2f"% metrics.mean_squared_error(y_test_2,y_pred_2))
print('R2: %.2f' % metrics.r2_score(y_test_2,y_pred_2))
print('RMSE: %.2f' % np.sqrt(metrics.mean_squared_error(y_test_2, y_pred_2)))
# Out:
# 6.26912964161
# [ -0.92584778   0.02957343   8.99180086 -18.7361472   11.48707789
#   -8.45029551  14.24805757]
# MSE: 4.85
# R2: 0.50
# RMSE: 2.20

# %%
# Plot the residule to ovbserve the non-linearality 
plt.figure(figsize=(12,4))
residual_2 = y_test_2 - y_pred_2

# Plot the residual vs. predicted value to observe if the right type of equation is used, and if Variance is constant.
# In this case, apparently not. 
plt.subplot(1,2,1)
plt.scatter(x=y_pred_2, y=residual_2)
plt.xlabel('prediction values (Number of Rings)')
plt.ylabel('Residual')

# Error terms should have a Normal Distribution
plt.subplot(1,2,2)
residual_2.hist()
plt.xlabel('Residual')
# Out:
# Text(0.5,0,'Residual')

# %% [markdown]
# Observation: The linear regression is not a very good model for this dataset.

# %%
# observe the weight has a log pattern influence on number of rings, a quandratic pattern of length is used. 
average_weight = data[["Whole weight","Shucked weight","Shell weight","Viscera weight"]].mean(axis=1)
len(average_weight)
# Out:
# 4177

# %%
#data.loc[:,'log_weight'] = np.log(data.loc[:,'Whole weight'])
data_num.loc[:,'size'] = [a*b for a,b in zip(data['Length'],data['Diameter'])]
data_num.loc[:,'log_weight'] = average_weight.apply(lambda x:np.log(x))
data_num.loc[:,'length^2'] = data_num['Length']**2

# %%
feature_cols_3 =["Sex_I","Sex_M","log_weight","Whole weight","Height","length^2"] 
X_3 = data_num[feature_cols_3]
y_3 = data_num["Rings"]
X_train_3, X_test_3, y_train_3, y_test_3 = train_test_split(X_3, y_3, test_size=0.2, random_state=1)

# %%
# instantiate
linreg_3 = LinearRegression()
# fit the model to the training data (learn the coefficients)
linreg.fit(X_train_3, y_train_3)
print(linreg.intercept_)
print(linreg.coef_)

# pair the feature names with the coefficients
list(zip(feature_cols, linreg.coef_))

# make predictions on the testing set
y_pred_3 = linreg.predict(X_test_3)

#Model evaluation
print("MSE: %.2f"% metrics.mean_squared_error(y_test_3,y_pred_3))
print('R2: %.2f' % metrics.r2_score(y_test_3,y_pred_3))
print('RMSE: %.2f' % np.sqrt(metrics.mean_squared_error(y_test_3, y_pred_3)))
# Out:
# 11.1126557223
# [ -1.04336183  -0.15658821   1.5747765    1.46222212  14.42684221
#   -7.55542357]
# MSE: 6.22
# R2: 0.36
# RMSE: 2.49

# %%
# Plot the residule to ovbserve the non-linearality 
plt.figure(figsize=(12,4))
residual_3 = y_test_3 - y_pred_3

# Plot the residual vs. predicted value to observe if the right type of equation is used, and if Variance is constant.
# In this case, apparently not. 
plt.subplot(1,2,1)
plt.scatter(x=y_pred_3, y=residual_3)
plt.xlabel('prediction values (Number of Rings)')
plt.ylabel('Residual')

plt.subplot(1,2,2)
# Error terms should have a Normal Distribution
residual_3.hist()
plt.xlabel('Residual')
# Out:
# Text(0.5,0,'Residual')

# %% [markdown]
# ### KNN

# %% [markdown]
# #### Using cross-validation to select the best K (with lowest MSE)

# %%
from sklearn.cross_validation import KFold
m = len(X)  #total number of samples
kf = KFold(m, n_folds=5, shuffle=False)
for iteration, data in enumerate(kf, start=1):
    print(str(iteration)+"\n","Training set",data[0].shape,"Testing set",data[1].shape)
# Out:
# 1
#  Training set (3341,) Testing set (836,)
# 2
#  Training set (3341,) Testing set (836,)
# 3
#  Training set (3342,) Testing set (835,)
# 4
#  Training set (3342,) Testing set (835,)
# 5
#  Training set (3342,) Testing set (835,)

# %%
from sklearn.cross_validation import cross_val_score
k_range = list(range(1, 31))
k_mse = []
k_best = 1
for k in k_range:
    #scores = cross_val_score(knn, X, y, cv=5, scoring='neg_mean_squared_error')
    scores_k = []
    for iteration, data in enumerate(kf, start=1):
        knn = KNeighborsRegressor(n_neighbors = k)
        x_train_thisfold = X.iloc[data[0],:]
        y_train_thisfold = y[data[0]]
        x_test_thisfold = X.iloc[data[1],:]
        y_test_thisfold = y[data[1]]
        
        knn.fit(x_train_thisfold, y_train_thisfold)
        y_pred_thisfold = knn.predict(x_test_thisfold)
        scores_thisfold = metrics.mean_squared_error(y_test_thisfold,y_pred_thisfold)
        scores_k.append(scores_thisfold)
        mse_this_k = sum(scores_k)/float(len(scores_k))
    k_mse.append(mse_this_k)
print(k_mse)
# Out:
# [8.4823370483912566, 6.6837309113829759, 5.8913891515215182, 5.6376478562014727, 5.4927698249434149, 5.3552405794471669, 5.3182206312889306, 5.2979888100593069, 5.2588272754508694, 5.2388776466206348, 5.220172314629707, 5.2208584306665777, 5.2334448285841049, 5.236031807101547, 5.2342963221881593, 5.2568715305632754, 5.2540353051616018, 5.2606053001210054, 5.2698834538110102, 5.2605398669168846, 5.2808027131623545, 5.2981160438030974, 5.3122117722207918, 5.3125948521617046, 5.3296731224250058, 5.3372505355925561, 5.3474886834125082, 5.3572354830179503, 5.3650140680356078, 5.3752773311431365]

# %%
plt.figure(figsize=(10,6), dpi=80)
plt.scatter(x = k_range, y = k_mse)
plt.xlabel('Value of K for KNN')
plt.ylabel('Cross-Validated MSE')
plt.show()

# %% [markdown]
# k = 11 has the smallest CV MSE, therefore is the best.

# %%
from sklearn.neighbors import KNeighborsRegressor
knn = KNeighborsRegressor(n_neighbors=15)
# Fit the model on the training data.
knn.fit(X_train, y_train)
y_pred_knn = knn.predict(X_test)

# %%
# Compute the mean squared error of our predictions.
mse_knn = (((y_pred_knn - y_test) ** 2).sum()) / len(y_pred_knn)
print("MSE: %.2f"% mse_knn)
# Out:
# MSE: 4.73

# %%
# Plot the residule to ovbserve the non-linearality 
plt.figure(figsize=(12,4))
residual_knn = y_test - y_pred_knn

# Plot the residual vs. predicted value to observe if the right type of equation is used, and if Variance is constant.
# In this case, apparently not. 
plt.subplot(1,2,1)
plt.scatter(x=y_pred_knn, y=residual_knn)
plt.xlabel('prediction values (Number of Rings)')
plt.ylabel('Residual')

# Error terms should have a Normal Distribution
plt.subplot(1,2,2)
residual_knn.hist()
plt.xlabel('Residual')
# Out:
# Text(0.5,0,'Residual')

# %% [markdown]
# Obeservation and thoughts:
# 1. Comparing to linear regression, the residule is more close to a normal distribution. It seems to be like a f-statistic distribution shale, similar than the distrubution pattern of all four types of weight.
#
# 2. In the first figure: Residual vs. predicted value, there're multiple points corresponding to one input, also there're some strange pattern that shows the residuals are not random, and there's a high variance. Better model is needed. Considering random-forest.

# %% [markdown]
# ### Tree Regression

# %%
from sklearn.tree import DecisionTreeRegressor
# create an estimator, optionally specifying parameters
model = DecisionTreeRegressor()
# fit the estimator to the data
model.fit(X_train, y_train)
# apply the model to the test and training data
predicted_test_y = model.predict(X_test)
predicted_train_y = model.predict(X_train)

# %%
def scatter_y(true_y, predicted_y):
    """Scatter-plot the predicted vs true number of rings
    
    Plots:
       * predicted vs true number of rings
       * perfect agreement line
       * +2/-2 number dotted lines

    Returns the root mean square of the error
    """
    fig, ax = plt.subplots(figsize=(8, 8))
    ax.plot(true_y, predicted_y, '.k')
    
    ax.plot([0, 30], [0, 30], '--k')
    ax.plot([0, 30], [2, 32], ':k')
    ax.plot([2, 32], [0, 30], ':k')
    
    rms = (true_y - predicted_y).std()
    
    ax.text(25, 3,
            "Root Mean Square Error = %.2g" % rms,
            ha='right', va='bottom')

    ax.set_xlim(0, 30)
    ax.set_ylim(0, 30)
    
    ax.set_xlabel('True number of rings')
    ax.set_ylabel('Predicted number of rings')
    
    return rms

# %%
scatter_y(y_train, predicted_train_y)
plt.title("Training data")
scatter_y(y_test, predicted_test_y)
plt.title("Test data");

# %% [markdown]
# The Decision Tree overfits the training set, i.e. its parameters are fine tuned to reproduce the results of the training set but generalized badly to data not seen previously.
#
# To prevent this issue we specify a maximum depth of the decision tree of  10 , so that the estimator does not "specialize" too much on the training data

# %%
model = DecisionTreeRegressor(max_depth=10)
# fit the estimator to the data
model.fit(X_train, y_train)
# apply the model to the test and train data
predicted_test_y = model.predict(X_test)
predicted_train_y = model.predict(X_train)

# %%
scatter_y(y_train, predicted_train_y)
plt.title("Training data")
rms_decision_tree = scatter_y(y_test, predicted_test_y)
plt.title("Test data");

# %% [markdown]
# #### Fit a Random Forest estimator to the data

# %%
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor(n_estimators=5)
model.fit(X_train, y_train)
predicted_test_y = model.predict(X_test)
rms_random_forest = scatter_y(y_test, predicted_test_y)

# %%
print("Root Mean Square error decreases from %.2g to %.2g." % (rms_decision_tree, rms_random_forest))
# Out:
# Root Mean Square error decreases from 2.6 to 2.3.

# %% [markdown]
# Reference:
# 1. James, Introduction to statistical learning
# 2. blog, https://medium.com/@dhwajraj/learning-python-regression-analysis-part-9-tests-and-validity-for-regression-models-78dcd5cde3a1
# 2. blog, https://bids.github.io/2015-06-04-berkeley/intermediate-python/03-sklearn-abalone.html
